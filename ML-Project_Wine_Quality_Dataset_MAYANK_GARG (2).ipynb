# %%
#linear algebra
import numpy as np
import pandas as pd

# %%
#visualitiation tools
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
import pandas as pd
#given data imports
wine_dataset = pd.read_csv("winequality-red.csv")
wine_dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4               0.7            0             1.9      0.076
# 1               7.4               0.7            0             1.9      0.076
# 2               7.4               0.7            0             1.9      0.076
# 3               7.4               0.7            0             1.9      0.076
# 4               7.4               0.7            0             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 3218            7.4               0.7            0             1.9      0.076
# 3219            7.4               0.7            0             1.9      0.076
# 3220            7.4               0.7            0             1.9      0.076
# 3221            7.4               0.7            0             1.9      0.076
# 3222            7.4               0.7            0             1.9      0.076
#
# ...

# %%
import pandas as pd
df1 = pd.read_csv("winequality-white.csv")
df1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               6.3              0.30         0.34             1.6      0.049
# 3               6.3              0.30         0.34             1.6      0.049
# 4               6.3              0.30         0.34             1.6      0.049
# ...             ...               ...          ...             ...        ...
# 4895            6.7              0.26         0.39             1.1      0.040
# 4896            6.7              0.26         0.39             1.1      0.040
# 4897            6.7              0.26         0.39             1.1      0.040
# 4898            6.7              0.26         0.39             1.1      0.040
# 4899            6.7              0.26         0.39             1.1      0.040
#
# ...

# %%
#merging the two dataset
dfn = wine_dataset.append(df1,ignore_index=True).reset_index(drop=True)
dfn
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.4              0.70         0.00             1.9      0.076
# 2               7.4              0.70         0.00             1.9      0.076
# 3               7.4              0.70         0.00             1.9      0.076
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 8118            6.7              0.26         0.39             1.1      0.040
# 8119            6.7              0.26         0.39             1.1      0.040
# 8120            6.7              0.26         0.39             1.1      0.040
# 8121            6.7              0.26         0.39             1.1      0.040
# 8122            6.7              0.26         0.39             1.1      0.040
#
# ...

# %%
#drop target
actual_y = wine_dataset['quality']

# %%
f, ax = plt.subplots(figsize=(12, 6))
sns.distplot(actual_y)
print("Skew is: ", actual_y.skew())
# Out:
# C:\Users\Mayank Garg\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Skew is:  0.0

# %%
log_actual_y = np.log(actual_y)
f, ax = plt.subplots(figsize=(12, 6))
sns.distplot(log_actual_y)

print("Skew is: ", log_actual_y.skew())
# Out:
# C:\Users\Mayank Garg\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Skew is:  -1.759039009922717

# %%
# number of rows & columns in the dataset
wine_dataset.shape
# Out:
# (3223, 12)

# %%
wine_dataset.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4               0.7            0             1.9      0.076
# 1            7.4               0.7            0             1.9      0.076
# 2            7.4               0.7            0             1.9      0.076
# 3            7.4               0.7            0             1.9      0.076
# 4            7.4               0.7            0             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                   11                    34   0.9978  3.51       0.56
# 1                   11                    34   0.9978  3.51       0.56
# 2                   11                    34   0.9978  3.51       0.56
# 3                   11                    34   0.9978  3.51       0.56
# 4                   11                    34   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.4        6
# 2      9.4        7
# ...

# %%
wine_dataset.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
wine_dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count   3.223000e+03      3.223000e+03       3223.0    3.223000e+03
# mean    7.400000e+00      7.000000e-01          0.0    1.900000e+00
# std     2.789313e-13      1.243643e-14          0.0    7.750559e-14
# min     7.400000e+00      7.000000e-01          0.0    1.900000e+00
# 25%     7.400000e+00      7.000000e-01          0.0    1.900000e+00
# 50%     7.400000e+00      7.000000e-01          0.0    1.900000e+00
# 75%     7.400000e+00      7.000000e-01          0.0    1.900000e+00
# max     7.400000e+00      7.000000e-01          0.0    1.900000e+00
#
#           chlorides  free sulfur dioxide  total sulfur dioxide       density  \
# count  3.223000e+03               3223.0                3223.0  3.223000e+03
# mean   7.600000e-02                 11.0                  34.0  9.978000e-01
# std    4.760820e-15                  0.0                   0.0  6.295941e-14
# ...

# %%
plt.figure(figsize=(8, 6), dpi=80)
plt.scatter(x = wine_dataset['fixed acidity'], y = log_actual_y)
plt.ylabel('volatile acidity')
plt.xlabel('fixed acidity')
plt.show()

# %%
# number of values for each quality
sns.catplot(x='quality', data = wine_dataset, kind = 'count')

# %%
# volatile acidity vs Quality
plot = plt.figure(figsize=(5,5))
sns.barplot(x='quality', y = 'volatile acidity', data = wine_dataset)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='volatile acidity'>

# %%
# citric acid vs Quality
plot = plt.figure(figsize=(5,5))
sns.barplot(x='quality', y = 'citric acid', data = wine_dataset)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='citric acid'>

# %%
wine_dataset.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid               int64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide       int64
# total sulfur dioxide      int64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
# separate the data and Label
X = wine_dataset.drop('quality',axis=1)

# %%
print(X)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4               0.7            0             1.9      0.076
# 1               7.4               0.7            0             1.9      0.076
# 2               7.4               0.7            0             1.9      0.076
# 3               7.4               0.7            0             1.9      0.076
# 4               7.4               0.7            0             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 3218            7.4               0.7            0             1.9      0.076
# 3219            7.4               0.7            0             1.9      0.076
# 3220            7.4               0.7            0             1.9      0.076
# 3221            7.4               0.7            0             1.9      0.076
# 3222            7.4               0.7            0             1.9      0.076
#
# ...

# %%
corr_map = wine_dataset.corr()
fig, ax = plt.subplots(figsize=(20,16))
sns.heatmap(corr_map, vmax=.8, square=True, annot=True)
plt.show();

# %%
Y = wine_dataset['quality'].apply(lambda y_value: 1 if y_value>=7 else 0)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=3)

# %%
print(Y.shape, Y_train.shape, Y_test.shape)
# Out:
# (3223,) (2578,) (645,)

# %%
model = RandomForestClassifier()

# %%
model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy : ', test_data_accuracy)
# Out:
# Accuracy :  0.9984496124031008

# %%
input_data = (7.5,0.5,0.36,6.1,0.071,17.0,102.0,0.9978,3.35,0.8,10.5)

# changing the input data to a numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the data as we are predicting the label for only one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
print(prediction)

if (prediction[0]==1):
  print('Good Quality Wine')
else:
  print('Bad Quality Wine')
# Out:
# [1]
# Good Quality Wine
